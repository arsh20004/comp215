# %% [markdown]
# <a href="https://colab.research.google.com/github/arsh20004/comp215/blob/main/labs/lab04-more_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMP 215 - LAB 4
# ----------------
# #### Name(s): Arshpreet Singh Virk
# #### Date: 29 January 2025
#
# By the end of this lab you should be able to:
#   * use composition and inheritance in a `class` to categorize related information
#
#
# During this lab, you will be introduced to the following:
#   * something, something

# %% [markdown]
# ## Near Earth Objects (with more classes)
#
# We'll continue working with Near Earth Object data using NASA's API: https://api.nasa.gov/.  In Lab 3 we defined an Asteroid class that contained a simple data structure.  In this lab, we will be Here's a brief review from Lab 2 on how to use the API.

# %%
# import necessary modules
import datetime, json, requests
from pprint import pprint
from datetime import datetime

# %% [markdown]
# ### Review: make an API query
#
# Here's a query that gets the record for a single NEO that recently passed by.

# %%
#API_KEY = 'DEMO_KEY'  # substitute your API key here
API_KEY = 'aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'

def get_neos(start_date):
    """ Return a list of NEO for the week starting at start_date """
    url = f'https://api.nasa.gov/neo/rest/v1/feed?start_date={start_date}&api_key={API_KEY}'
    # Fetch last week's NEO feed
    response = requests.request("GET", url, headers={}, data={})
    data = json.loads(response.text)
    #pprint(data)
    print(f'{data["element_count"]} Near Earth Objects found for week of {start_date}')
    return [neo for dated_records in data['near_earth_objects'].values() for neo in dated_records ]

def get_neo(id):
    """ Return a NEO record for the given id """
    url = f'https://api.nasa.gov/neo/rest/v1/neo/{id}?api_key={API_KEY}'
    response = requests.request("GET", url, headers={}, data={})
    return json.loads(response.text)

week_start = '2023-01-15'
neos = get_neos(week_start)
assert len(neos) > 0, f'Oh oh!  No NEOs found for {week_start}'
# neo = get_neo(neos[-1]['id'])  # get the very latest NEO
# print(f"Record for NEO ID {neos[-1]['id']} is:")
pprint(neos)
# Out:
# 117 Near Earth Objects found for week of 2023-01-15
# [{'absolute_magnitude_h': 22.23,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 05:42',
#                            'epoch_date_close_approach': 1674366120000,
#                            'miss_distance': {'astronomical': '0.3163190211',
#                                              'kilometers': '47320651.797045057',
#                                              'lunar': '123.0480992079',
#                                              'miles': '29403689.5594815066'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '56313.1411535776',
#                                                  'kilometers_per_second': '15.6425392093',
#                                                  'miles_per_hour': '34990.7959573438'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 698.2726469645,
#                                   'estimated_diameter_min': 312.2770210883},
#                          'kilometers': {'estimated_diameter_max': 0.212833496,
#                                         'estimated_diameter_min': 0.095182033},
#                          'meters': {'estimated_diameter_max': 212.8334959841,
#                                     'estimated_diameter_min': 95.1820329819},
#                          'miles': {'estimated_diameter_max': 0.1322485622,
#                                    'estimated_diameter_min': 0.059143355}},
#   'id': '3370021',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3370021?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2007 EC)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3370021',
#   'neo_reference_id': '3370021'},
#  {'absolute_magnitude_h': 24.6,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 12:33',
#                            'epoch_date_close_approach': 1674390780000,
#                            'miss_distance': {'astronomical': '0.3068596053',
#                                              'kilometers': '45905543.341920711',
#                                              'lunar': '119.3683864617',
#                                              'miles': '28524381.9395033718'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '55193.5249981729',
#                                                  'kilometers_per_second': '15.3315347217',
#                                                  'miles_per_hour': '34295.1100190036'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 234.436392583,
#                                   'estimated_diameter_min': 104.8431420431},
#                          'kilometers': {'estimated_diameter_max': 0.0714562102,
#                                         'estimated_diameter_min': 0.0319561887},
#                          'meters': {'estimated_diameter_max': 71.4562101727,
#                                     'estimated_diameter_min': 31.9561886721},
#                          'miles': {'estimated_diameter_max': 0.0444008168,
#                                    'estimated_diameter_min': 0.0198566489}},
#   'id': '3554439',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3554439?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2010 YO)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3554439',
#   'neo_reference_id': '3554439'},
#  {'absolute_magnitude_h': 23.26,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 17:08',
#                            'epoch_date_close_approach': 1674407280000,
#                            'miss_distance': {'astronomical': '0.2649730292',
#                                              'kilometers': '39639400.775767804',
#                                              'lunar': '103.0745083588',
#                                              'miles': '24630781.4975475352'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '19316.0518780581',
#                                                  'kilometers_per_second': '5.3655699661',
#                                                  'miles_per_hour': '12002.2434572301'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 434.5352673318,
#                                   'estimated_diameter_min': 194.330079275},
#                          'kilometers': {'estimated_diameter_max': 0.1324463452,
#                                         'estimated_diameter_min': 0.0592318063},
#                          'meters': {'estimated_diameter_max': 132.4463452445,
#                                     'estimated_diameter_min': 59.2318062676},
#                          'miles': {'estimated_diameter_max': 0.082298318,
#                                    'estimated_diameter_min': 0.0368049267}},
#   'id': '3767162',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3767162?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2017 BL30)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3767162',
#   'neo_reference_id': '3767162'},
#  {'absolute_magnitude_h': 23.18,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 08:13',
#                            'epoch_date_close_approach': 1674375180000,
#                            'miss_distance': {'astronomical': '0.2111132109',
#                                              'kilometers': '31582086.679500783',
#                                              'lunar': '82.1230390401',
#                                              'miles': '19624198.6764574854'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '29857.1835025635',
#                                                  'kilometers_per_second': '8.293662084',
#                                                  'miles_per_hour': '18552.0927158012'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 450.8426875319,
#                                   'estimated_diameter_min': 201.622979296},
#                          'kilometers': {'estimated_diameter_max': 0.1374168468,
#                                         'estimated_diameter_min': 0.0614546821},
#                          'meters': {'estimated_diameter_max': 137.4168467624,
#                                     'estimated_diameter_min': 61.4546821229},
#                          'miles': {'estimated_diameter_max': 0.0853868435,
#                                    'estimated_diameter_min': 0.0381861573}},
#   'id': '3883106',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3883106?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2019 UD8)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3883106',
#   'neo_reference_id': '3883106'},
#  {'absolute_magnitude_h': 29.1,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 11:46',
#                            'epoch_date_close_approach': 1674387960000,
#                            'miss_distance': {'astronomical': '0.3093114506',
#                                              'kilometers': '46272334.176370222',
#                                              'lunar': '120.3221542834',
#                                              'miles': '28752295.1955521836'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '80757.2871318679',
#                                                  'kilometers_per_second': '22.4325797589',
#                                                  'miles_per_hour': '50179.4376625765'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 29.5137932072,
#                                   'estimated_diameter_min': 13.198969577},
#                          'kilometers': {'estimated_diameter_max': 0.0089958039,
#                                         'estimated_diameter_min': 0.0040230458},
#                          'meters': {'estimated_diameter_max': 8.9958038817,
#                                     'estimated_diameter_min': 4.0230457983},
#                          'miles': {'estimated_diameter_max': 0.0055897317,
#                                    'estimated_diameter_min': 0.002499804}},
#   'id': '54110694',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54110694?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2021 CS2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54110694',
#   'neo_reference_id': '54110694'},
#  {'absolute_magnitude_h': 21.94,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 17:07',
#                            'epoch_date_close_approach': 1674407220000,
#                            'miss_distance': {'astronomical': '0.4918982356',
#                                              'kilometers': '73586928.302518172',
#                                              'lunar': '191.3484136484',
#                                              'miles': '45724796.9601758936'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32661.3892566203',
#                                                  'kilometers_per_second': '9.0726081268',
#                                                  'miles_per_hour': '20294.5171189261'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 798.0406799921,
#                                   'estimated_diameter_min': 356.8946418545},
#                          'kilometers': {'estimated_diameter_max': 0.2432427915,
#                                         'estimated_diameter_min': 0.1087814834},
#                          'meters': {'estimated_diameter_max': 243.2427914778,
#                                     'estimated_diameter_min': 108.7814833562},
#                          'miles': {'estimated_diameter_max': 0.1511440166,
#                                    'estimated_diameter_min': 0.0675936591}},
#   'id': '54137811',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54137811?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2021 GP16)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54137811',
#   'neo_reference_id': '54137811'},
#  {'absolute_magnitude_h': 22.14,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 05:19',
#                            'epoch_date_close_approach': 1674364740000,
#                            'miss_distance': {'astronomical': '0.1926044121',
#                                              'kilometers': '28813209.802762227',
#                                              'lunar': '74.9231163069',
#                                              'miles': '17903698.3659116526'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '34086.3765033234',
#                                                  'kilometers_per_second': '9.4684379176',
#                                                  'miles_per_hour': '21179.9487778567'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 727.8217503997,
#                                   'estimated_diameter_min': 325.4917818793},
#                          'kilometers': {'estimated_diameter_max': 0.2218400624,
#                                         'estimated_diameter_min': 0.0992098919},
#                          'meters': {'estimated_diameter_max': 221.8400624229,
#                                     'estimated_diameter_min': 99.2098919421},
#                          'miles': {'estimated_diameter_max': 0.1378449814,
#                                    'estimated_diameter_min': 0.0616461498}},
#   'id': '54336231',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54336231?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2022 YJ2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54336231',
#   'neo_reference_id': '54336231'},
#  {'absolute_magnitude_h': 27.15,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 02:50',
#                            'epoch_date_close_approach': 1674355800000,
#                            'miss_distance': {'astronomical': '0.009679415',
#                                              'kilometers': '1448019.86684605',
#                                              'lunar': '3.765292435',
#                                              'miles': '899757.82293349'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '19931.4522263589',
#                                                  'kilometers_per_second': '5.5365145073',
#                                                  'miles_per_hour': '12384.6293014284'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 72.4477713214,
#                                   'estimated_diameter_min': 32.3996282986},
#                          'kilometers': {'estimated_diameter_max': 0.02208208,
#                                         'estimated_diameter_min': 0.0098754064},
#                          'meters': {'estimated_diameter_max': 22.0820799921,
#                                     'estimated_diameter_min': 9.8754063894},
#                          'miles': {'estimated_diameter_max': 0.0137211641,
#                                    'estimated_diameter_min': 0.0061362911}},
#   'id': '54338828',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54338828?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 AE1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338828',
#   'neo_reference_id': '54338828'},
#  {'absolute_magnitude_h': 27.45,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 20:55',
#                            'epoch_date_close_approach': 1674420900000,
#                            'miss_distance': {'astronomical': '0.0036422586',
#                                              'kilometers': '544874.128549182',
#                                              'lunar': '1.4168385954',
#                                              'miles': '338569.0838234316'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '34637.8532776219',
#                                                  'kilometers_per_second': '9.6216259105',
#                                                  'miles_per_hour': '21522.6149990868'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 63.0993709944,
#                                   'estimated_diameter_min': 28.2188965762},
#                          'kilometers': {'estimated_diameter_max': 0.0192326877,
#                                         'estimated_diameter_min': 0.0086011194},
#                          'meters': {'estimated_diameter_max': 19.2326876637,
#                                     'estimated_diameter_min': 8.6011194012},
#                          'miles': {'estimated_diameter_max': 0.0119506344,
#                                    'estimated_diameter_min': 0.0053444862}},
#   'id': '54339972',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54339972?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BH2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54339972',
#   'neo_reference_id': '54339972'},
#  {'absolute_magnitude_h': 23.81,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 04:20',
#                            'epoch_date_close_approach': 1674361200000,
#                            'miss_distance': {'astronomical': '0.1102984351',
#                                              'kilometers': '16500410.955293237',
#                                              'lunar': '42.9060912539',
#                                              'miles': '10252879.9352591906'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '65060.8012405537',
#                                                  'kilometers_per_second': '18.072444789',
#                                                  'miles_per_hour': '40426.2517486096'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 337.3067483398,
#                                   'estimated_diameter_min': 150.8481637115},
#                          'kilometers': {'estimated_diameter_max': 0.1028110936,
#                                         'estimated_diameter_min': 0.0459785188},
#                          'meters': {'estimated_diameter_max': 102.811093604,
#                                     'estimated_diameter_min': 45.9785188279},
#                          'miles': {'estimated_diameter_max': 0.063883832,
#                                    'estimated_diameter_min': 0.0285697182}},
#   'id': '54340099',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340099?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BY3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340099',
#   'neo_reference_id': '54340099'},
#  {'absolute_magnitude_h': 25.92,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 13:24',
#                            'epoch_date_close_approach': 1674393840000,
#                            'miss_distance': {'astronomical': '0.0145137262',
#                                              'kilometers': '2171222.525283194',
#                                              'lunar': '5.6458394918',
#                                              'miles': '1349135.1169843172'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '30203.133920409',
#                                                  'kilometers_per_second': '8.3897594223',
#                                                  'miles_per_hour': '18767.052851823'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 127.6512376842,
#                                   'estimated_diameter_min': 57.0873689748},
#                          'kilometers': {'estimated_diameter_max': 0.038908096,
#                                         'estimated_diameter_min': 0.0174002295},
#                          'meters': {'estimated_diameter_max': 38.9080960011,
#                                     'estimated_diameter_min': 17.4002295067},
#                          'miles': {'estimated_diameter_max': 0.0241763625,
#                                    'estimated_diameter_min': 0.010811998}},
#   'id': '54340444',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340444?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BN8)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340444',
#   'neo_reference_id': '54340444'},
#  {'absolute_magnitude_h': 21.68,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 23:35',
#                            'epoch_date_close_approach': 1674430500000,
#                            'miss_distance': {'astronomical': '0.197630837',
#                                              'kilometers': '29565152.26151719',
#                                              'lunar': '76.878395593',
#                                              'miles': '18370933.743789622'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '60203.524561798',
#                                                  'kilometers_per_second': '16.7232012672',
#                                                  'miles_per_hour': '37408.1289145238'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 899.5494244116,
#                                   'estimated_diameter_min': 402.290732421},
#                          'kilometers': {'estimated_diameter_max': 0.2741826558,
#                                         'estimated_diameter_min': 0.1226182113},
#                          'meters': {'estimated_diameter_max': 274.1826557868,
#                                     'estimated_diameter_min': 122.6182113181},
#                          'miles': {'estimated_diameter_max': 0.170369151,
#                                    'estimated_diameter_min': 0.0761914006}},
#   'id': '54340712',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340712?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BW9)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340712',
#   'neo_reference_id': '54340712'},
#  {'absolute_magnitude_h': 20.8,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 13:21',
#                            'epoch_date_close_approach': 1674393660000,
#                            'miss_distance': {'astronomical': '0.1944902502',
#                                              'kilometers': '29095327.165687074',
#                                              'lunar': '75.6567073278',
#                                              'miles': '18078997.9664826612'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '58965.267140379',
#                                                  'kilometers_per_second': '16.3792408723',
#                                                  'miles_per_hour': '36638.7239073094'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1349.040630575,
#                                   'estimated_diameter_min': 603.309310875},
#                          'kilometers': {'estimated_diameter_max': 0.411187571,
#                                         'estimated_diameter_min': 0.1838886721},
#                          'meters': {'estimated_diameter_max': 411.1875710413,
#                                     'estimated_diameter_min': 183.8886720703},
#                          'miles': {'estimated_diameter_max': 0.2555000322,
#                                    'estimated_diameter_min': 0.1142630881}},
#   'id': '54341485',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54341485?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 CO1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54341485',
#   'neo_reference_id': '54341485'},
#  {'absolute_magnitude_h': 22.93,
#   'close_approach_data': [{'close_approach_date': '2023-01-22',
#                            'close_approach_date_full': '2023-Jan-22 00:41',
#                            'epoch_date_close_approach': 1674348060000,
#                            'miss_distance': {'astronomical': '0.0939857845',
#                                              'kilometers': '14060073.171479015',
#                                              'lunar': '36.5604701705',
#                                              'miles': '8736524.350739807'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '50572.6865763998',
#                                                  'kilometers_per_second': '14.0479684934',
#                                                  'miles_per_hour': '31423.9007229858'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 505.8538153978,
#                                   'estimated_diameter_min': 226.2247035814},
#                          'kilometers': {'estimated_diameter_max': 0.154184238,
#                                         'estimated_diameter_min': 0.0689532874},
#                          'meters': {'estimated_diameter_max': 154.1842379994,
#                                     'estimated_diameter_min': 68.9532874451},
#                          'miles': {'estimated_diameter_max': 0.0958056141,
#                                    'estimated_diameter_min': 0.0428455732}},
#   'id': '54341543',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54341543?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 CD2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54341543',
#   'neo_reference_id': '54341543'},
#  {'absolute_magnitude_h': 16.74,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 23:56',
#                            'epoch_date_close_approach': 1674258960000,
#                            'miss_distance': {'astronomical': '0.4232995108',
#                                              'kilometers': '63324705.187721996',
#                                              'lunar': '164.6635097012',
#                                              'miles': '39348147.2058197048'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '89783.5911701908',
#                                                  'kilometers_per_second': '24.9398864362',
#                                                  'miles_per_hour': '55788.0319690555'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 8750.3420524656,
#                                   'estimated_diameter_min': 3913.2719311376},
#                          'kilometers': {'estimated_diameter_max': 2.6671041722,
#                                         'estimated_diameter_min': 1.1927652464},
#                          'meters': {'estimated_diameter_max': 2667.1041722442,
#                                     'estimated_diameter_min': 1192.7652464423},
#                          'miles': {'estimated_diameter_max': 1.6572611866,
#                                    'estimated_diameter_min': 0.7411497339}},
#   'id': '2139345',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2139345?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '139345 (2001 KA67)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2139345',
#   'neo_reference_id': '2139345'},
#  {'absolute_magnitude_h': 18.7,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 10:30',
#                            'epoch_date_close_approach': 1674210600000,
#                            'miss_distance': {'astronomical': '0.2133845507',
#                                              'kilometers': '31921874.275627009',
#                                              'lunar': '83.0065902223',
#                                              'miles': '19835332.8982663642'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '89000.4453973358',
#                                                  'kilometers_per_second': '24.7223459437',
#                                                  'miles_per_hour': '55301.4156414724'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 3548.3383903678,
#                                   'estimated_diameter_min': 1586.8651696069},
#                          'kilometers': {'estimated_diameter_max': 1.0815335068,
#                                         'estimated_diameter_min': 0.4836764882},
#                          'meters': {'estimated_diameter_max': 1081.533506775,
#                                     'estimated_diameter_min': 483.6764882185},
#                          'miles': {'estimated_diameter_max': 0.6720335566,
#                                    'estimated_diameter_min': 0.3005425432}},
#   'id': '3392297',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3392297?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2007 UB66)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3392297',
#   'neo_reference_id': '3392297'},
#  {'absolute_magnitude_h': 24.3,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 08:04',
#                            'epoch_date_close_approach': 1674201840000,
#                            'miss_distance': {'astronomical': '0.4461989259',
#                                              'kilometers': '66750408.910927833',
#                                              'lunar': '173.5713821751',
#                                              'miles': '41476780.7933687754'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '59250.5724411281',
#                                                  'kilometers_per_second': '16.4584923448',
#                                                  'miles_per_hour': '36816.0015259887'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 269.1689931548,
#                                   'estimated_diameter_min': 120.3760332259},
#                          'kilometers': {'estimated_diameter_max': 0.0820427065,
#                                         'estimated_diameter_min': 0.0366906138},
#                          'meters': {'estimated_diameter_max': 82.0427064882,
#                                     'estimated_diameter_min': 36.6906137531},
#                          'miles': {'estimated_diameter_max': 0.0509789586,
#                                    'estimated_diameter_min': 0.0227984834}},
#   'id': '3734647',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3734647?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2015 VE106)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3734647',
#   'neo_reference_id': '3734647'},
#  {'absolute_magnitude_h': 27.43,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 13:17',
#                            'epoch_date_close_approach': 1674220620000,
#                            'miss_distance': {'astronomical': '0.1410070806',
#                                              'kilometers': '21094358.912678322',
#                                              'lunar': '54.8517543534',
#                                              'miles': '13107426.8288799636'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '15404.0651366863',
#                                                  'kilometers_per_second': '4.2789069824',
#                                                  'miles_per_hour': '9571.4870289593'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 63.6832222857,
#                                   'estimated_diameter_min': 28.4800028114},
#                          'kilometers': {'estimated_diameter_max': 0.0194106455,
#                                         'estimated_diameter_min': 0.0086807046},
#                          'meters': {'estimated_diameter_max': 19.4106455316,
#                                     'estimated_diameter_min': 8.6807045791},
#                          'miles': {'estimated_diameter_max': 0.0120612122,
#                                    'estimated_diameter_min': 0.0053939381}},
#   'id': '54087767',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54087767?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2020 VA4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54087767',
#   'neo_reference_id': '54087767'},
#  {'absolute_magnitude_h': 20.08,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 09:42',
#                            'epoch_date_close_approach': 1674207720000,
#                            'miss_distance': {'astronomical': '0.0797900934',
#                                              'kilometers': '11936428.019741058',
#                                              'lunar': '31.0383463326',
#                                              'miles': '7416952.4428122804'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '39271.2455604582',
#                                                  'kilometers_per_second': '10.9086793223',
#                                                  'miles_per_hour': '24401.6247761636'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1879.4251319352,
#                                   'estimated_diameter_min': 840.5044707257},
#                          'kilometers': {'estimated_diameter_max': 0.5728487619,
#                                         'estimated_diameter_min': 0.2561857545},
#                          'meters': {'estimated_diameter_max': 572.8487618827,
#                                     'estimated_diameter_min': 256.1857544793},
#                          'miles': {'estimated_diameter_max': 0.355951608,
#                                    'estimated_diameter_min': 0.1591863984}},
#   'id': '54328941',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54328941?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2022 WS4)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54328941',
#   'neo_reference_id': '54328941'},
#  {'absolute_magnitude_h': 20.85,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 07:41',
#                            'epoch_date_close_approach': 1674200460000,
#                            'miss_distance': {'astronomical': '0.3123808627',
#                                              'kilometers': '46731511.688682449',
#                                              'lunar': '121.5161555903',
#                                              'miles': '29037614.8712538362'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '47828.01519526',
#                                                  'kilometers_per_second': '13.2855597765',
#                                                  'miles_per_hour': '29718.4686639658'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1318.3327167796,
#                                   'estimated_diameter_min': 589.5763143362},
#                          'kilometers': {'estimated_diameter_max': 0.4018277992,
#                                         'estimated_diameter_min': 0.1797028549},
#                          'meters': {'estimated_diameter_max': 401.8277992159,
#                                     'estimated_diameter_min': 179.7028548592},
#                          'miles': {'estimated_diameter_max': 0.2496841414,
#                                    'estimated_diameter_min': 0.1116621426}},
#   'id': '54335605',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54335605?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2022 YP1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54335605',
#   'neo_reference_id': '54335605'},
#  {'absolute_magnitude_h': 27.04,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 04:00',
#                            'epoch_date_close_approach': 1674187200000,
#                            'miss_distance': {'astronomical': '0.0294711883',
#                                              'kilometers': '4408826.996048921',
#                                              'lunar': '11.4642922487',
#                                              'miles': '2739518.0622042698'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '26040.5214127394',
#                                                  'kilometers_per_second': '7.2334781702',
#                                                  'miles_per_hour': '16180.5673189324'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 76.2122932736,
#                                   'estimated_diameter_min': 34.0831736962},
#                          'kilometers': {'estimated_diameter_max': 0.0232295062,
#                                         'estimated_diameter_min': 0.010388551},
#                          'meters': {'estimated_diameter_max': 23.2295062464,
#                                     'estimated_diameter_min': 10.3885510102},
#                          'miles': {'estimated_diameter_max': 0.0144341415,
#                                    'estimated_diameter_min': 0.0064551443}},
#   'id': '54338712',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54338712?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 AT)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338712',
#   'neo_reference_id': '54338712'},
#  {'absolute_magnitude_h': 26.02,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 15:03',
#                            'epoch_date_close_approach': 1674226980000,
#                            'miss_distance': {'astronomical': '0.0265864395',
#                                              'kilometers': '3977274.720083865',
#                                              'lunar': '10.3421249655',
#                                              'miles': '2471363.912392737'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '18512.4042705272',
#                                                  'kilometers_per_second': '5.1423345196',
#                                                  'miles_per_hour': '11502.8880868729'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 121.9059855849,
#                                   'estimated_diameter_min': 54.5180141264},
#                          'kilometers': {'estimated_diameter_max': 0.0371569432,
#                                         'estimated_diameter_min': 0.0166170902},
#                          'meters': {'estimated_diameter_max': 37.1569432173,
#                                     'estimated_diameter_min': 16.617090174},
#                          'miles': {'estimated_diameter_max': 0.023088247,
#                                    'estimated_diameter_min': 0.0103253779}},
#   'id': '54339963',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54339963?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BZ1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54339963',
#   'neo_reference_id': '54339963'},
#  {'absolute_magnitude_h': 24.99,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 12:04',
#                            'epoch_date_close_approach': 1674216240000,
#                            'miss_distance': {'astronomical': '0.0725961057',
#                                              'kilometers': '10860222.783014859',
#                                              'lunar': '28.2398851173',
#                                              'miles': '6748229.5178046942'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '19496.8369738919',
#                                                  'kilometers_per_second': '5.4157880483',
#                                                  'miles_per_hour': '12114.5762852497'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 195.8957572256,
#                                   'estimated_diameter_min': 87.607245932},
#                          'kilometers': {'estimated_diameter_max': 0.0597090249,
#                                         'estimated_diameter_min': 0.0267026877},
#                          'meters': {'estimated_diameter_max': 59.7090248917,
#                                     'estimated_diameter_min': 26.7026877056},
#                          'miles': {'estimated_diameter_max': 0.0371014565,
#                                    'estimated_diameter_min': 0.0165922758}},
#   'id': '54340042',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340042?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BW2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340042',
#   'neo_reference_id': '54340042'},
#  {'absolute_magnitude_h': 28.31,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 03:02',
#                            'epoch_date_close_approach': 1674183720000,
#                            'miss_distance': {'astronomical': '0.0095521466',
#                                              'kilometers': '1428980.785287742',
#                                              'lunar': '3.7157850274',
#                                              'miles': '887927.4862331596'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22073.0514439641',
#                                                  'kilometers_per_second': '6.1314031789',
#                                                  'miles_per_hour': '13715.3357708343'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 42.4644037055,
#                                   'estimated_diameter_min': 18.9906586619},
#                          'kilometers': {'estimated_diameter_max': 0.0129431498,
#                                         'estimated_diameter_min': 0.0057883526},
#                          'meters': {'estimated_diameter_max': 12.9431498352,
#                                     'estimated_diameter_min': 5.7883525749},
#                          'miles': {'estimated_diameter_max': 0.008042498,
#                                    'estimated_diameter_min': 0.0035967144}},
#   'id': '54340261',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340261?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BJ5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340261',
#   'neo_reference_id': '54340261'},
#  {'absolute_magnitude_h': 24.32,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 23:11',
#                            'epoch_date_close_approach': 1674256260000,
#                            'miss_distance': {'astronomical': '0.0609945281',
#                                              'kilometers': '9124651.485415147',
#                                              'lunar': '23.7268714309',
#                                              'miles': '5669795.5211251486'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '38976.2177195506',
#                                                  'kilometers_per_second': '10.8267271443',
#                                                  'miles_per_hour': '24218.3059491285'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 266.7012369924,
#                                   'estimated_diameter_min': 119.2724191197},
#                          'kilometers': {'estimated_diameter_max': 0.0812905344,
#                                         'estimated_diameter_min': 0.0363542322},
#                          'meters': {'estimated_diameter_max': 81.290534434,
#                                     'estimated_diameter_min': 36.3542321843},
#                          'miles': {'estimated_diameter_max': 0.0505115807,
#                                    'estimated_diameter_min': 0.0225894656}},
#   'id': '54340276',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340276?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BY5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340276',
#   'neo_reference_id': '54340276'},
#  {'absolute_magnitude_h': 23.89,
#   'close_approach_data': [{'close_approach_date': '2023-01-20',
#                            'close_approach_date_full': '2023-Jan-20 17:16',
#                            'epoch_date_close_approach': 1674234960000,
#                            'miss_distance': {'astronomical': '0.0301886755',
#                                              'kilometers': '4516161.552921185',
#                                              'lunar': '11.7433947695',
#                                              'miles': '2806212.663174953'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '38968.3821824741',
#                                                  'kilometers_per_second': '10.8245506062',
#                                                  'miles_per_hour': '24213.4372511045'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 325.1060339141,
#                                   'estimated_diameter_min': 145.3918383455},
#                          'kilometers': {'estimated_diameter_max': 0.099092316,
#                                         'estimated_diameter_min': 0.0443154309},
#                          'meters': {'estimated_diameter_max': 99.0923159661,
#                                     'estimated_diameter_min': 44.3154309096},
#                          'miles': {'estimated_diameter_max': 0.0615730915,
#                                    'estimated_diameter_min': 0.0275363236}},
#   'id': '54340801',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
# ...
#                                                  'kilometers_per_second': '24.9976194551',
#                                                  'miles_per_hour': '55917.1749590922'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 542.0321288269,
#                                   'estimated_diameter_min': 242.4041372092},
#                          'kilometers': {'estimated_diameter_max': 0.1652113876,
#                                         'estimated_diameter_min': 0.0738847787},
#                          'meters': {'estimated_diameter_max': 165.2113875797,
#                                     'estimated_diameter_min': 73.884778657},
#                          'miles': {'estimated_diameter_max': 0.1026575651,
#                                    'estimated_diameter_min': 0.0459098588}},
#   'id': '54338708',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54338708?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 AQ)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54338708',
#   'neo_reference_id': '54338708'},
#  {'absolute_magnitude_h': 23.34,
#   'close_approach_data': [{'close_approach_date': '2023-01-17',
#                            'close_approach_date_full': '2023-Jan-17 02:47',
#                            'epoch_date_close_approach': 1673923620000,
#                            'miss_distance': {'astronomical': '0.0230378467',
#                                              'kilometers': '3446412.795706529',
#                                              'lunar': '8.9617223663',
#                                              'miles': '2141501.6085029402'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '57744.4527056232',
#                                                  'kilometers_per_second': '16.0401257516',
#                                                  'miles_per_hour': '35880.157293669'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 418.8177024426,
#                                   'estimated_diameter_min': 187.3009705684},
#                          'kilometers': {'estimated_diameter_max': 0.1276556316,
#                                         'estimated_diameter_min': 0.057089334},
#                          'meters': {'estimated_diameter_max': 127.6556316195,
#                                     'estimated_diameter_min': 57.0893340024},
#                          'miles': {'estimated_diameter_max': 0.0793215075,
#                                    'estimated_diameter_min': 0.0354736566}},
#   'id': '54339765',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54339765?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BB1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54339765',
#   'neo_reference_id': '54339765'},
#  {'absolute_magnitude_h': 23.34,
#   'close_approach_data': [{'close_approach_date': '2023-01-17',
#                            'close_approach_date_full': '2023-Jan-17 10:26',
#                            'epoch_date_close_approach': 1673951160000,
#                            'miss_distance': {'astronomical': '0.1350432201',
#                                              'kilometers': '20202178.084901187',
#                                              'lunar': '52.5318126189',
#                                              'miles': '12553051.3692309006'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '73052.6753431436',
#                                                  'kilometers_per_second': '20.2924098175',
#                                                  'miles_per_hour': '45392.091520855'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 418.8177024426,
#                                   'estimated_diameter_min': 187.3009705684},
#                          'kilometers': {'estimated_diameter_max': 0.1276556316,
#                                         'estimated_diameter_min': 0.057089334},
#                          'meters': {'estimated_diameter_max': 127.6556316195,
#                                     'estimated_diameter_min': 57.0893340024},
#                          'miles': {'estimated_diameter_max': 0.0793215075,
#                                    'estimated_diameter_min': 0.0354736566}},
#   'id': '54340258',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54340258?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BF5)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54340258',
#   'neo_reference_id': '54340258'},
#  {'absolute_magnitude_h': 25.05,
#   'close_approach_data': [{'close_approach_date': '2023-01-17',
#                            'close_approach_date_full': '2023-Jan-17 23:44',
#                            'epoch_date_close_approach': 1673999040000,
#                            'miss_distance': {'astronomical': '0.0293560741',
#                                              'kilometers': '4391606.156922167',
#                                              'lunar': '11.4195128249',
#                                              'miles': '2728817.5289612246'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '44098.9061112904',
#                                                  'kilometers_per_second': '12.249696142',
#                                                  'miles_per_hour': '27401.3453000959'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 190.5570539909,
#                                   'estimated_diameter_min': 85.2197052631},
#                          'kilometers': {'estimated_diameter_max': 0.0580817882,
#                                         'estimated_diameter_min': 0.0259749653},
#                          'meters': {'estimated_diameter_max': 58.0817881978,
#                                     'estimated_diameter_min': 25.974965333},
#                          'miles': {'estimated_diameter_max': 0.0360903388,
#                                    'estimated_diameter_min': 0.0161400902}},
#   'id': '54468274',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54468274?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2024 RF2)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54468274',
#   'neo_reference_id': '54468274'},
#  {'absolute_magnitude_h': 20.89,
#   'close_approach_data': [{'close_approach_date': '2023-01-18',
#                            'close_approach_date_full': '2023-Jan-18 13:46',
#                            'epoch_date_close_approach': 1674049560000,
#                            'miss_distance': {'astronomical': '0.4976726236',
#                                              'kilometers': '74450764.447871732',
#                                              'lunar': '193.5946505804',
#                                              'miles': '46261559.8508726216'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '69972.4679684458',
#                                                  'kilometers_per_second': '19.4367966579',
#                                                  'miles_per_hour': '43478.1704440601'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1294.2704329143,
#                                   'estimated_diameter_min': 578.8153338529},
#                          'kilometers': {'estimated_diameter_max': 0.3944936153,
#                                         'estimated_diameter_min': 0.1764229081},
#                          'meters': {'estimated_diameter_max': 394.4936153285,
#                                     'estimated_diameter_min': 176.4229081128},
#                          'miles': {'estimated_diameter_max': 0.2451268923,
#                                    'estimated_diameter_min': 0.1096240788}},
#   'id': '3605885',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3605885?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2012 MO3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3605885',
#   'neo_reference_id': '3605885'},
#  {'absolute_magnitude_h': 23.53,
#   'close_approach_data': [{'close_approach_date': '2023-01-18',
#                            'close_approach_date_full': '2023-Jan-18 02:53',
#                            'epoch_date_close_approach': 1674010380000,
#                            'miss_distance': {'astronomical': '0.2140564514',
#                                              'kilometers': '32022389.189198518',
#                                              'lunar': '83.2679595946',
#                                              'miles': '19897789.9693868284'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '7588.1173194172',
#                                                  'kilometers_per_second': '2.1078103665',
#                                                  'miles_per_hour': '4714.9610088346'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 383.7293606038,
#                                   'estimated_diameter_min': 171.6089870545},
#                          'kilometers': {'estimated_diameter_max': 0.1169607054,
#                                         'estimated_diameter_min': 0.0523064176},
#                          'meters': {'estimated_diameter_max': 116.9607053693,
#                                     'estimated_diameter_min': 52.3064175804},
#                          'miles': {'estimated_diameter_max': 0.0726759905,
#                                    'estimated_diameter_min': 0.032501691}},
#   'id': '3797409',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/3797409?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2018 AV)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=3797409',
#   'neo_reference_id': '3797409'},
#  {'absolute_magnitude_h': 26.9,
#   'close_approach_data': [{'close_approach_date': '2023-01-18',
#                            'close_approach_date_full': '2023-Jan-18 20:46',
#                            'epoch_date_close_approach': 1674074760000,
#                            'miss_distance': {'astronomical': '0.4056337387',
#                                              'kilometers': '60681943.309656569',
#                                              'lunar': '157.7915243543',
#                                              'miles': '37706011.1216518922'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '43969.7359867367',
#                                                  'kilometers_per_second': '12.2138155519',
#                                                  'miles_per_hour': '27321.0840079809'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 81.2877363957,
#                                   'estimated_diameter_min': 36.3529808636},
#                          'kilometers': {'estimated_diameter_max': 0.0247765013,
#                                         'estimated_diameter_min': 0.0110803882},
#                          'meters': {'estimated_diameter_max': 24.7765012606,
#                                     'estimated_diameter_min': 11.0803882126},
#                          'miles': {'estimated_diameter_max': 0.0153953994,
#                                    'estimated_diameter_min': 0.0068850319}},
#   'id': '54054597',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54054597?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2020 SW3)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54054597',
#   'neo_reference_id': '54054597'},
#  {'absolute_magnitude_h': 23.55,
#   'close_approach_data': [{'close_approach_date': '2023-01-18',
#                            'close_approach_date_full': '2023-Jan-18 21:12',
#                            'epoch_date_close_approach': 1674076320000,
#                            'miss_distance': {'astronomical': '0.2700993146',
#                                              'kilometers': '40406282.152619902',
#                                              'lunar': '105.0686333794',
#                                              'miles': '25107299.4886905676'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '19099.6570510935',
#                                                  'kilometers_per_second': '5.305460292',
#                                                  'miles_per_hour': '11867.7841271086'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 380.2113086795,
#                                   'estimated_diameter_min': 170.0356664043},
#                          'kilometers': {'estimated_diameter_max': 0.1158884032,
#                                         'estimated_diameter_min': 0.0518268695},
#                          'meters': {'estimated_diameter_max': 115.8884031771,
#                                     'estimated_diameter_min': 51.8268694616},
#                          'miles': {'estimated_diameter_max': 0.072009693,
#                                    'estimated_diameter_min': 0.0322037137}},
#   'id': '54339244',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54339244?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BO)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54339244',
#   'neo_reference_id': '54339244'},
#  {'absolute_magnitude_h': 24.86,
#   'close_approach_data': [{'close_approach_date': '2023-01-18',
#                            'close_approach_date_full': '2023-Jan-18 17:45',
#                            'epoch_date_close_approach': 1674063900000,
#                            'miss_distance': {'astronomical': '0.0823813629',
#                                              'kilometers': '12324076.417537023',
#                                              'lunar': '32.0463501681',
#                                              'miles': '7657825.9877479974'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '42918.8831905878',
#                                                  'kilometers_per_second': '11.9219119974',
#                                                  'miles_per_hour': '26668.1249469516'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 207.9816551205,
#                                   'estimated_diameter_min': 93.0122237845},
#                          'kilometers': {'estimated_diameter_max': 0.0633928065,
#                                         'estimated_diameter_min': 0.0283501249},
#                          'meters': {'estimated_diameter_max': 63.3928064522,
#                                     'estimated_diameter_min': 28.3501249023},
#                          'miles': {'estimated_diameter_max': 0.0393904515,
#                                    'estimated_diameter_min': 0.0176159455}},
#   'id': '54339874',
#   'is_potentially_hazardous_asteroid': False,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54339874?api_key=aBc4UUtzD7XKTjicJqoBBf7MWz4N76r7sbqU2peF'},
#   'name': '(2023 BM1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54339874',
#   'neo_reference_id': '54339874'}]

# %% [markdown]
# ## Exercise 1: Define a CloseApproach class
#
# Each NEO record comes with a list of `close_approach_data`, where each record in this list represents a single “close approach” to another orbiting body.
# 1. Develop a class named `CloseApproach` to represent a single close approach record.  State variables are
#
#         neo (refrence to related NEO object)
#         orbiting body (str)
#         approach date (datetime object!)
#         miss distance (float - choose units, document it, and be consistent!)
#         relative velocity (ditto)
#
# 2. Define a "Factory" class method to construct a `CloseApproach` object from one close approach data record (a dictionary object). This method takes a `neo` object as input for the NEO to which the close approach data belongs. Remember to parse the date/time string into a datetime object.

# %%
from dataclasses import dataclass
@dataclass

class CloseApproach:
    def __init__(self, neo, orbiting_body: str, approach_date: datetime, miss_distance: float, relative_velocity: float):

        self.neo = neo
        self.orbiting_body = orbiting_body
        self.approach_date = approach_date
        self.miss_distance = miss_distance
        self.relative_velocity = relative_velocity  #

    @classmethod
    def from_dict(cls, neo, data: dict):

        approach_date = datetime.strptime(data['close_approach_date'], "%Y-%m-%d")
        miss_distance = float(data['miss_distance']['kilometers'])
        relative_velocity = float(data['relative_velocity']['kilometers_per_hour'])

        return cls(
            neo=neo,
            orbiting_body=data['orbiting_body'],
            approach_date=approach_date,
            miss_distance=miss_distance,
            relative_velocity=relative_velocity
        )

# %%
neo_data = neos[0]
close_approaches = neo_data["close_approach_data"]
close_approach_data = close_approaches[0]

close_approach = CloseApproach.from_dict(neo_object, close_approach_data)

# print(f"NEO: {neo_object}")
print(f"Close Approach: {vars(close_approach)}")
# Out:
# Close Approach: {'neo': NEO(id='3370021', name='(2007 EC)', estimated_diameter=212.8334959841, is_potentially_hazardous=False), 'orbiting_body': 'Earth', 'approach_date': datetime.datetime(2023, 1, 22, 0, 0), 'miss_distance': 47320651.79704506, 'relative_velocity': 56313.1411535776}

# %% [markdown]
# ## Exercise 2: Add list of CloseApproach objects to the Asteroid
#
# Define an `Asteroid` class, like you did in Lab 3, but give the `Asteroid` list of “close approaches”.  This is called *composition* because each Asteroid object will be *composed* of CloseApproach objects (plus some other things).  There is bit of a catch-22 here because we need the `Asteroid` to construct the `CloseApproach` objects. The first two steps deal with that:
#
# 1. Add an instance variable to your Asteroid class with a default value of an empty list:
#
#     ```
#     close_approaches:list = []
#     ```
#
# 2. In the Asteroid `from_NEO` factory, use a list comprehension to build the list of `CloseApproach` objects for the Asteroid instance, and then set the instance's `close_approaches` variable before returning it. Setting the value of an object's instance variables from outside the class is generally frowned upon - this is why we make the factory a method of the class itself.
#
# 3. Add a method to `Asteroid` to return the `CloseApproach` object for the nearest miss (ie. smallest `missed_distance`):
#     ```
#     def nearest_miss(self):
#         ...
#     ```
#
# 4. Add a method to the Asteroid class, `closest_earth_approach`, that returns the CloseApproach object that represents the closest approach the Asteroid makes to Earth.
#     ```
#     def closest_earth_approach(self):
#         ...
#     ```
#
# Write some test code to demonstrate these new features.

# %%
# Ex. 2 your code here

# %% [markdown]
# ## Exercise 3: Plot the Closest Approaches
#
# Write a function that takes an Asteroid object as a parameter and makes a timeline plot of close approaches.  You may wish to use the `matplotlib.pyplot` `plot` object.  Here is an example of a timeline plot for the asteroid with neo id '54339874'
#
# ![Screenshot 2025-01-02 at 10.35.29 AM.png](data:image/png;base64,...)

# %%
# Ex. 3 your code here

# %% [markdown]
# ## Challenge - Take your skills to the next level...
#
#  With these data structures in place, we can now start answering all kinds of interesting questions about a single Asteroid or a set of Asteroids.
# Here’s a couple ideas to try:
#
#
#
# * write a **function** named `most_dangerous_approach`, that takes a date range and returns a single “potentially hazardous” Asteroid object that makes the closest approach to Earth in within that range.  Your algorithm will ultimately need to:
#     * grab the list of NEO’s for the given date range;
#     * use a list comprehension to build the list of Asteroid objects for the NEO’s returned
#     * use a list comprehension to filter  potentially hazardous Asteroids only;
#     * use a list comprehension to map each Asteroid to its  closest_earth_approach
#     * apply Python’s min function to identify the Asteroid with the closest_earth_approach
#
# You may want to decompose some of these steps into smaller functions.
# * add a method to the Asteroid class, estimated_mass, that computes an estimate of the Asteroid’s mass based on its diameter.  This is a model – state your assumptions.
# * add a method to the CloseApproach class, impact_force,  that estimates the force of impact if the Asteroid hit the orbiting object.  Again, this is a model, state your assumptions.

# %%
# Ex. 5 (challenge) your code here
